# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from prophet import Prophet
from functions import load_data, replace_missing_long, widen_data, feature_engineering, normalize_data, group_data, remove_outliers, remove_incorrect_values, clean_data, iqr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cl/gr0w_0nd5b98g5nsjqhms9t40000gn/T/ipykernel_41512/3802010132.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 from prophet import Prophet
# ----> 5 from functions import load_data, replace_missing_long, widen_data, feature_engineering, normalize_data, group_data, remove_outliers, remove_incorrect_values, clean_data, iqr
#
# ~/Library/CloudStorage/GoogleDrive-timmooren9@gmail.com/My Drive/Master AI/DM/DM1/functions.py in <module>
#     160
#     161
# --> 162 def split_data(data=clean_data()):
#     163     # Split data into train and test
#     164     train = data[data['time'] < '2014-04-01']
#
# ~/Library/CloudStorage/GoogleDrive-timmooren9@gmail.com/My Drive/Master AI/DM/DM1/functions.py in clean_data(data)
#     155     data = impute_missing_wide(data)
#     156     data = normalize_data(data)
# ...

# %% [markdown]
# ## Task 2: Modelling

# %%
data = clean_data()
data
# Out:
# variable       time  appCat.builtin  appCat.communication  \
# 15       2014-03-04        0.000000              0.000000
# 16       2014-03-05        0.000000              0.000000
# 17       2014-03-06        0.000000              0.000000
# 18       2014-03-07        0.000000              0.000000
# 19       2014-03-08        0.000000              0.000000
# ..              ...             ...                   ...
# 107      2014-06-04        0.079846              1.000000
# 108      2014-06-05        0.178465              0.193606
# 109      2014-06-06        0.090180              0.322837
# 110      2014-06-07        1.000000              0.289729
# 111      2014-06-08        0.294400              0.622678
#
# variable  appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# 15                         0.0             0.0          0.0            0.0
# 16                         0.0             0.0          0.0            0.0
# ...

# %% [markdown]
# ## TASK 1C: FEATURE ENGINEERING

# %%
data = feature_engineering(data)
